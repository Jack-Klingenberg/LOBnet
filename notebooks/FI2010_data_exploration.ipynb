# %%
import torch 
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
os.listdir("../data/published/BenchmarkDatasets/BenchmarkDatasets/NoAuction/1.NoAuction_Zscore/NoAuction_Zscore_Training")
# Out:
# ['Train_Dst_NoAuction_ZScore_CF_5.txt',
#  'Train_Dst_NoAuction_ZScore_CF_9.txt',
#  'Train_Dst_NoAuction_ZScore_CF_7.txt',
#  'Train_Dst_NoAuction_ZScore_CF_3.txt',
#  'Train_Dst_NoAuction_ZScore_CF_1.txt',
#  'Train_Dst_NoAuction_ZScore_CF_2.txt',
#  'Train_Dst_NoAuction_ZScore_CF_4.txt',
#  'Train_Dst_NoAuction_ZScore_CF_6.txt',
#  'Train_Dst_NoAuction_ZScore_CF_8.txt']

# %%
sample_data = np.loadtxt("/home/jackklingenberg/Projects/LOBnet/data/published/BenchmarkDatasets/BenchmarkDatasets/Auction/1.Auction_Zscore/Auction_Zscore_Testing/Test_Dst_Auction_ZScore_CF_1.txt")

# %%
sample_features = sample_data[0:40,:].T
sample_labels = sample_data[-5:,:].T

# %%
sample_labels
# Out:
# array([[2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2.],
#        [2., 1., 2., 2., 2.],
#        ...,
#        [2., 2., 2., 3., 3.],
#        [2., 2., 2., 3., 3.],
#        [2., 3., 3., 3., 3.]])

# %%
plt.hist(sample_labels[:,0])
# Out:
# (array([ 8112.,     0.,     0.,     0.,     0., 29140.,     0.,     0.,
#             0.,  7862.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(sample_labels[:,1])
# Out:
# (array([10914.,     0.,     0.,     0.,     0., 23756.,     0.,     0.,
#             0., 10444.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(sample_labels[:,4])
# Out:
# (array([18951.,     0.,     0.,     0.,     0.,  8717.,     0.,     0.,
#             0., 17446.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)
