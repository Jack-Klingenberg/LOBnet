# %%
import wrds

# %%
conn = wrds.Connection()
# Out:
# Enter your WRDS username [jackklingenberg]: klingeja
# Enter your password: ········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?:  n
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
conn.list_libraries().sort()
type(conn.list_libraries())
# Out:
# list

# %%
conn.list_libraries()
# Out:
# ['aha',
#  'aha_hcris_recent',
#  'aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_acct_os',
#  'audit_audit_comp',
#  'audit_common',
#  'audit_corp_legal',
#  'auditsmp',
#  'auditsmp_all',
#  'bank',
#  'bank_all',
#  'bank_premium_samp',
#  'banksamp',
#  'block',
#  'block_all',
#  'boardex',
#  'boardex_na',
#  'boardex_trial',
#  'boardsmp',
#  'bvd',
#  'bvd_ama_large',
#  'bvd_ama_medium',
#  'bvd_ama_small',
#  'bvd_ama_verylarge',
#  'bvd_amadeus_trial',
#  'bvd_bvdbankf_trial',
#  'bvd_orbis_trial',
#  'bvdsamp',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'cboe_all',
#  'cboe_sample',
#  'cboesamp',
#  'ciq',
#  'ciq_common',
#  'ciqsamp',
#  'ciqsamp_capstrct',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_pplintel',
#  'ciqsamp_ratings',
#  'ciqsamp_transactions',
#  'ciqsamp_transcripts',
#  'cisdmsmp',
#  'columnar',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_global',
#  'comp_global_daily',
# ...

# %% [markdown]
# > NBBO = National Best Bid & Offer, CQM = quotes, CTM = trades

# %%
for tbl in conn.list_tables(library='taqm_2014'):
    print(tbl)
# Out:
# complete_nbbo_2014
# complete_nbbo_20140102
# complete_nbbo_20140103
# complete_nbbo_20140106
# complete_nbbo_20140107
# complete_nbbo_20140108
# complete_nbbo_20140109
# complete_nbbo_20140110
# complete_nbbo_20140113
# complete_nbbo_20140114
# complete_nbbo_20140115
# complete_nbbo_20140116
# complete_nbbo_20140117
# complete_nbbo_20140121
# complete_nbbo_20140122
# complete_nbbo_20140123
# complete_nbbo_20140124
# complete_nbbo_20140127
# complete_nbbo_20140128
# complete_nbbo_20140129
# complete_nbbo_20140130
# complete_nbbo_20140131
# complete_nbbo_20140203
# complete_nbbo_20140204
# complete_nbbo_20140205
# complete_nbbo_20140206
# complete_nbbo_20140207
# complete_nbbo_20140210
# complete_nbbo_20140211
# complete_nbbo_20140212
# complete_nbbo_20140213
# complete_nbbo_20140214
# complete_nbbo_20140218
# complete_nbbo_20140219
# complete_nbbo_20140220
# complete_nbbo_20140221
# complete_nbbo_20140224
# complete_nbbo_20140225
# complete_nbbo_20140226
# complete_nbbo_20140227
# ...

# %%
company = conn.get_table(library='taqm_2014', table='nbbom_20141215', obs=5)

# %%
print(",\n".join(company.columns))
# Out:
# date,
# time_m,
# ex,
# sym_root,
# sym_suffix,
# bid,
# bidsiz,
# ask,
# asksiz,
# qu_cond,
# mmid,
# bidex,
# askex,
# qu_seqnum,
# natbbo_ind,
# nasdbbo_ind,
# qu_cancel,
# qu_source,
# nbbo_qu_cond,
# best_bidex,
# best_bid,
# best_bidsiz,
# best_bid_mm,
# best_bid_mm_location,
# best_bid_mm_desk_location,
# best_askex,
# best_ask,
# best_asksiz,
# best_ask_mm,
# best_ask_mm_location,
# best_ask_mm_desk_location,
# luld_nbbo_cqs,
# luld_nbbo_utp,
# luld_indicator,
# luld_nbbo_indicator,
# sip_message_id

# %%
company.head()
# Out:
#          date           time_m ex sym_root sym_suffix    bid  bidsiz    ask  \
# 0  2014-12-15  06:32:58.303000  T        A       None      0       0  43.17
# 1  2014-12-15  06:33:24.099000  T        A       None  36.23       2  43.17
# 2  2014-12-15  07:13:54.612000  T        A       None  39.73       2  43.17
# 3  2014-12-15  07:24:36.217000  T        A       None      0       0  43.17
# 4  2014-12-15  07:24:36.218000  T        A       None  38.92       2  43.17
#
#    asksiz qu_cond  ... best_ask best_asksiz best_ask_mm  best_ask_mm_location  \
# 0       1       R  ...    43.17           1        None                  None
# 1       1       R  ...    43.16           2        None                  None
# 2       1       R  ...    43.16           2        None                  None
# 3       1       R  ...    43.16           2        None                  None
# 4       1       R  ...    43.16           2        None                  None
#
# ...
